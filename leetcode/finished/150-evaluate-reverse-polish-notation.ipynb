# %% [markdown]
# # 150. Evaluate Reverse Polish Notation
#
# Evaluate an arithmetic expression written in Reverse Polish Notation.
#
# Each token is either an integer or one of `+`, `-`, `*`, `/`. Division should truncate toward zero.
#
# ## Examples
#
# **Input:** `tokens = ["2","1","+","3","*"]`
# **Output:** `9`
#
# **Input:** `tokens = ["4","13","5","/","+"]`
# **Output:** `6`
#
# **Input:** `tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]`
# **Output:** `22`
#
# ## Constraints
#
# - `1 <= tokens.length <= 10^4`
# - Each token is either an operator (`+`, `-`, `*`, `/`) or an integer in the range `[-200, 200]`.
# - The input expression is valid Reverse Polish Notation.
# - Division by zero will not occur.
# - Division between two integers truncates toward zero.
# - Every intermediate result and the final result fit in a 32-bit signed integer.

# %%
from typing import List

class Solution:
    def evalRPN(self, tokens: List[str]) -> int:
        stack = []
        cases = ["+", "-", "*", "/"]
        for token in tokens:
            if token not in cases:
                stack.append(int(token))
            else:
                b = stack.pop()
                a = stack.pop()
                if token == "+":
                    stack.append(a + b)
                elif token == "-":
                    stack.append(a - b)
                elif token == "*":
                    stack.append(a * b)
                elif token == "/":
                    quotient = abs(a) // abs(b)
                    if (a < 0) != (b < 0):
                        quotient = -quotient
                    stack.append(quotient)

        return stack[0]

# %%
sol = Solution()

test_cases = [
    ["2", "1", "+", "3", "*"],
    ["4", "13", "5", "/", "+"],
    ["10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+"],
]

for tokens in test_cases:
    result = sol.evalRPN(tokens)
    print(f"input={tokens}")
    print(f"output={result}")
    print()
# Out:
# input=['2', '1', '+', '3', '*']
# output=9
#
# input=['4', '13', '5', '/', '+']
# output=6
#
# input=['10', '6', '9', '3', '+', '-11', '*', '/', '*', '17', '+', '5', '+']
# output=22
