# %% [markdown]
# ## Binary Search
#
# Given an array of integers `nums` which is sorted in ascending order, and an integer `target`, write a function to search for `target` in `nums`.
#
# If `target` exists, return its index. Otherwise, return `-1`.
#
# You must write an algorithm with **O(log n)** runtime complexity.
#
# ### Example 1
#
# **Input:**
# `nums = [-1,0,3,5,9,12], target = 9`
#
# **Output:**
# `4`
#
# **Explanation:**
# `9` exists in `nums` and its index is `4`.
#
# ### Example 2
#
# **Input:**
# `nums = [-1,0,3,5,9,12], target = 2`
#
# **Output:**
# `-1`
#
# **Explanation:**
# `2` does not exist in `nums`, so return `-1`.
#
# ### Constraints
#
# * `1 <= nums.length <= 10^4`
# * `-10^4 < nums[i], target < 10^4`
# * All the integers in `nums` are unique.
# * `nums` is sorted in ascending order.

# %%
def brute_search(nums, target):
    for i in range(len(nums)):
        if nums[i] == target:
            return i
    return -1

def binary_search_iterative(nums, target):
    def bsr(nums, target, left, right):
        if left > right:
            return -1
        mid = (left + right) // 2
        if nums[mid] < target:
            return bsr(nums, target, mid + 1, right)
        elif nums[mid] > target:
            return bsr(nums, target, left, mid - 1)
        else:
            return mid

    return bsr(nums, target, 0, len(nums)-1)

def binary_search_iterative(nums, target):
    left = 0
    right = len(nums)-1
    while left <= right:
        mid = (left + right) //2
        if nums[mid] < target:
            left = mid + 1
        elif nums[mid] > target:
            right = mid - 1
        else:
            return mid

# %%
nums1 = [-1,0,3,5,9,12]
target1 = 9

nums2 = [-1,0,3,5,9,12]
nums2 = []
target2 = 2

print("Brute")
print(brute_search(nums1, target1))
print(brute_search(nums2, target2))
print("Binary Recursive")
print(binary_search_recursive(nums1, target1))
print(binary_search_recursive(nums2, target2))
print("Binary Iterative")
print(binary_search_iterative(nums1, target1))
print(binary_search_iterative(nums2, target2))
# Out:
# Brute
# 4
# -1
# Binary Recursive
# 4
# -1
# Binary Iterative
# 4
# -1
